# %% [markdown]
# # Chapter 02. 자료형 (Data types)
# ## 02-1. 숫자형(number)

# %%
# 정수형
a = 123
print(a)
# Out:
# 123

# %%
a = -178

# %%
a
# Out:
# -178

# %%
a = 0
a
# Out:
# 0

# %%
# 실수형
a = 1.2
a
# Out:
# 1.2

# %%
a = -3.45
a
# Out:
# -3.45

# %%
# 실수형 > 컴퓨터식 지수 표현 방식
a = 4.24E10
a
# Out:
# 42400000000.0

# %%
a = 4.24e-10
a
# Out:
# 4.24e-10

# %%
# 8진수와 16진수
a = 0o177
a
# Out:
# 127

# %%
a = 0x8ff
b = 0xABC
print(a, b)
# Out:
# 2303 2748

# %% [markdown]
# ### 연산자

# %%
# 사칙연산
a = 3
b = 4
a + b
# Out:
# 7

# %%
a - b
# Out:
# -1

# %%
a * b
# Out:
# 12

# %%
a / b
# Out:
# 0.75

# %%
# 제곱 연산자 **
a = 3
b = 4
a ** b
# Out:
# 81

# %%
# 복잡한 계산
10 * 18 ** 2 + 2 * 11
# Out:
# 3262

# %%
# 나머지 연산자
print(7 % 3)
print(3 % 7)
# Out:
# 1
# 3

# %%
# 몫을 반환하는 // 연산자
print(7 / 4)
print(7 // 4)
# Out:
# 1.75
# 1

# %%
# 14를 3으로 나누었을때의 몫과 나머지
print(14 // 3)
print(14 % 3)
# Out:
# 4
# 2
